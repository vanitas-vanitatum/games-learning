# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.figure(figsize=(16, 12))

aa = pd.read_csv('deepqlearning_analysis.csv')
aa['MeanRewardX'].plot(figsize=(16, 12))

# %%
sliding_window_results = []

aa['MeanRewardO'].rolling(100).mean().plot()

# %%
aa[aa['Winner'] == 0]
# Out:
#         Epsilon  MeanLoss  MeanRewardO  MeanRewardX  StartingPlayer  Winner
# 4      0.599800  0.101416          0.0          0.0              -1       0
# 5      0.599750  0.099919          0.0          0.0               1       0
# 12     0.599400  0.157266          0.0          0.0              -1       0
# 14     0.599300  0.211041          0.0          0.0               1       0
# 15     0.599251  0.142837          0.0          0.0              -1       0
# 17     0.599151  0.223664          0.0          0.0               1       0
# 27     0.598652  0.186868          0.0          0.0              -1       0
# 42     0.597904  0.294865          0.0          0.0              -1       0
# 45     0.597755  0.278550          0.0          0.0              -1       0
# 50     0.597506  0.228584          0.0          0.0               1       0
# 72     0.596413  0.294219          0.0          0.0               1       0
# ...

# %%
aa['MeanLoss'].rolling(100).mean().plot()
